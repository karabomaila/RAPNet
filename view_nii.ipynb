# %%
import nibabel as nib
import matplotlib.pyplot as plt
import cv2

# %%
support_img = nib.load('./data/CHAOST2/niis/T2SPIR/normalized/image_15.nii.gz')
support_mask = nib.load('./data/CHAOST2/niis/T2SPIR/normalized/label_15.nii.gz')

prediction_mask = nib.load('./data/prediction/prediction_15_LIVER.nii.gz')

# %%
print("Support image: ", support_img.shape, "Support mask: ", support_mask.shape)
prediction_mask.shape
# Out:
# Support image:  (256, 256, 36) Support mask:  (256, 256, 36)
# (256, 256, 10)

# %%
plt.imshow(support_img.get_fdata()[:, :, 8], cmap='gray')
plt.show()

# %%
plt.imshow(support_mask.get_fdata()[:, :, 8], cmap='gray')
plt.show()

# %%
plt.imshow(1- nifti_img.get_fdata()[:, :, 8], cmap='gray')
plt.show()
